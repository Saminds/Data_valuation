# %%
import pandas as pd
import matplotlib.pyplot as plt
import pickle
with open('fmnist_cnn_100_Clients[100]_6_FedAvg.pkl', 'rb') as file:
    fedavg_noise6 = pickle.load(file)
fedavg_noise6.keys()
# Out:
# dict_keys(['train_loss', 'train_accuracy', 'test_accuracy'])

# %%
fedavg_noise61 = fedavg_noise6['test_accuracy']
plt.plot(fedavg_noise61)
plt.title('Noise6')
plt.xlabel('Number of Rounds')  # This should be the x-axis label
plt.ylabel('Accuracy')  # And this is the correct y-axis label
plt.show()
